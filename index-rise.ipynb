# %% [markdown]
# # Video Lectures and Live Slides
#
# ## Introduction to Unix

# %%
from IPython.lib.display import YouTubeVideo
YouTubeVideo('Cz8LNMF3azM')

# %% [markdown]
# **Live Slides:** [Basic Unix Commands - Users and System](BasicUnixCommands-Users_and_System-rise.ipynb)

# %% [markdown]
# ## Basic Unix Commands - File System Navigation

# %%
YouTubeVideo('3_vgwWTo1Vk')

# %% [markdown]
# **Slides:** [Basic Unix Commands - File System Navigation](BasicUnixCommands-FileSystem-rise.ipynb)

# %% [markdown]
# ## git and Github

# %%
YouTubeVideo('XupOhni5pTc')

# %% [markdown]
# **Slides:** [git and Github](git_and_Github-rise.ipynb)

# %% [markdown]
# ## Basic Unix Commands - Users & System

# %%
YouTubeVideo('njxYqYw-LVk')

# %% [markdown]
# **Slides:** [Basic Unix Commands - Users & System](BasicUnixCommands-Users_and_System-rise.ipynb)

# %% [markdown]
# ## Basic Unix Commands - File Content Handling

# %%
YouTubeVideo('PiES7jQxc9U')

# %% [markdown]
# **Slides:** [Basic Unix Commands - File Content Handling](BasicUnixCommands-FileContentHandling-rise.ipynb)

# %% [markdown]
# ## Basic Unix Commands - Pipes & Redirects

# %%
YouTubeVideo('pqzBCaRHoEI')

# %% [markdown]
# **Slides:** [Basic Unix Commands - Pipes & Redirects](BasicUnixCommands-Pipes_and_Redirects-rise.ipynb)

# %% [markdown]
# ## Basic Unix Commands - Pipes & Redirects

# %%
YouTubeVideo('PIbiD6OciI0')

# %% [markdown]
# **Slides:** [Basic Unix Commands - File Attributes](BasicUnixCommands-FileAtrributes-rise.ipynb)

# %% [markdown]
# ## Basic Unix Commands - Find

# %%
YouTubeVideo('Hz5SDYM-nDM')

# %% [markdown]
# **Slides:** [Basic Unix Commands - Find](BasicUnixCommands-Find-rise.ipynb)

# %% [markdown]
# ## Basic Unix Commands - Regular Expressions

# %%
YouTubeVideo('vCuxdmjrWCE')

# %% [markdown]
# **Slides:** [Basic Unix Commands - Regular Expressions](BasicUnixCommands-Regular_Expressions-rise.ipynb)

# %% [markdown]
# ## Basic Unix Commands - grep

# %%
YouTubeVideo('VGT2JesUl5s')

# %% [markdown]
# **Slides:** [Basic Unix Commands - grep](BasicUnixCommands-grep-rise.ipynb)

# %% [markdown]
# ## vi/vim Editor

# %%
YouTubeVideo('w3Kfb33C3sM')

# %% [markdown]
# **Slides:** [vi/vim Editor](vi-vim-rise.ipynb)

# %% [markdown]
# ## Customizing vim

# %%
YouTubeVideo('7o9qX2bnybA')

# %% [markdown]
# **Slides:** [Customizing vim](CustomizingVim.pdf)

# %% [markdown]
# ## The Bash Shell

# %%
YouTubeVideo('79Oh-7KNP2s')

# %% [markdown]
# **Slides:** [The Bash Shell](BashShell.pdf)

# %% [markdown]
# ## Customizing Bash

# %%
YouTubeVideo('mMcYzQkQ3b0')

# %% [markdown]
# **Slides:** [Customizing Bash](CustomizingBash.pdf)

# %% [markdown]
# ## Branching, merging, and Github Pull Requests

# %%
YouTubeVideo('3LmPjqGI-x8')

# %% [markdown]
# ## Jupyter Notebooks and Python Functions

# %%
YouTubeVideo('RlwPBT4Uqhw')

# %% [markdown]
# **Notebook:** [Jupyter Notebook & Python Functions](JupyterNotebook_and_Python_Functions-rise.ipynb)

# %% [markdown]
# ## Python Lists, Tuples, & Dictonaries

# %%
YouTubeVideo('NyILHJ0JxqY')

# %% [markdown]
# ## Python Loops & Conditionals

# %%
YouTubeVideo('1wQTyjPtrlY')

# %% [markdown]
# ## Python Classes & Object-Oriented Programming

# %%
YouTubeVideo('sOQ-usIoZuQ')

# %% [markdown]
# ## Numpy

# %%
YouTubeVideo('GHCZOvjXGto')

# %% [markdown]
# **Slides:** [Numpy](Numpy-rise.ipynb)

# %% [markdown]
# ## Scipy

# %%
YouTubeVideo('hhDkdPRe01o')

# %% [markdown]
# **Slides:** [Scipy](Scipy-rise.ipynb)

# %% [markdown]
# # maplotlib

# %%
YouTubeVideo('FNJc3ByKpRs')

# %% [markdown]
# **Slides:** [matplotlib](matplotlib-rise.ipynb)

# %% [markdown]
# # SWIG

# %%
YouTubeVideo('g8--GrdlqGw')

# %% [markdown]
# **Slides:** [SWIG](swig.pdf)

# %% [markdown]
# # CMake

# %%
YouTubeVideo('1marFAayuDQ')

# %% [markdown]
# **Slides:** [CMake](CMake-rise.ipynb)

# %% [markdown]
# # CFFI

# %%
YouTubeVideo('EhavJLpGNGM')

# %% [markdown]
# **Slides:** [CFFI](CFFI-rise.ipynb)

# %%
# %%javascript
# function hideElements(elements, start) {
#     for(var i = 0, length = elements.length; i < length;i++) {
#         if(i >= start) {
#             elements[i].style.display = "none";
#         }
#     }
# }
#
# var prompt_elements = document.getElementsByClassName("prompt");
# hideElements(prompt_elements, 0)
